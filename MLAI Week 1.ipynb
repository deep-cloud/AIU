# %%
import turicreate as tc

# %%
# Load labels
labels = tc.SFrame.read_csv('labels.txt', delimiter=' ', header=False, verbose=False)
labels = labels.rename({'X1': 'exp_id', 'X2': 'user_id', 'X3': 'activity_id', 'X4': 'start', 'X5': 'end'})
labels
# Out:
# Columns:
# 	exp_id	int
# 	user_id	int
# 	activity_id	int
# 	start	int
# 	end	int
#
# Rows: 1214
#
# Data:
# +--------+---------+-------------+-------+------+
# | exp_id | user_id | activity_id | start | end  |
# +--------+---------+-------------+-------+------+
# |   1    |    1    |      5      |  250  | 1232 |
# |   1    |    1    |      7      |  1233 | 1392 |
# |   1    |    1    |      4      |  1393 | 2194 |
# |   1    |    1    |      8      |  2195 | 2359 |
# |   1    |    1    |      5      |  2360 | 3374 |
# |   1    |    1    |      11     |  3375 | 3662 |
# |   1    |    1    |      6      |  3663 | 4538 |
# |   1    |    1    |      10     |  4539 | 4735 |
# |   1    |    1    |      4      |  4736 | 5667 |
# |   1    |    1    |      9      |  5668 | 5859 |
# +--------+---------+-------------+-------+------+
# [1214 rows x 5 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
# Out:
# Columns:
# 	exp_id	int
# 	user_id	int
# 	activity_id	int
# 	start	int
# 	end	int
#
# Rows: 1214
#
# Data:
# +--------+---------+-------------+-------+------+
# | exp_id | user_id | activity_id | start | end  |
# +--------+---------+-------------+-------+------+
# |   1    |    1    |      5      |  250  | 1232 |
# |   1    |    1    |      7      |  1233 | 1392 |
# |   1    |    1    |      4      |  1393 | 2194 |
# |   1    |    1    |      8      |  2195 | 2359 |
# |   1    |    1    |      5      |  2360 | 3374 |
# |   1    |    1    |      11     |  3375 | 3662 |
# |   1    |    1    |      6      |  3663 | 4538 |
# |   1    |    1    |      10     |  4539 | 4735 |
# |   1    |    1    |      4      |  4736 | 5667 |
# |   1    |    1    |      9      |  5668 | 5859 |
# +--------+---------+-------------+-------+------+
# [1214 rows x 5 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.
